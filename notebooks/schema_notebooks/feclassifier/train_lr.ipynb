# %%
cd ../../..
# Out:
# c:\Users\RAZER\Desktop\QuickDraw-ML

# %%
from schema.training.feclassifier import TransformersFEClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from xgboost import XGBClassifier

# %%
DATA_DIR = 'data/img'

# %%
with open(f'data/labels.txt') as f:
    labels = f.read().splitlines()

label2idx = {label: idx for idx, label in enumerate(labels)}

# %%
print(label2idx)
# Out:
# {'airplane': 0, 'banana': 1, 'computer': 2, 'dog': 3, 'elephant': 4, 'fish': 5, 'garden': 6, 'helmet': 7, 'ice cream': 8, 'jail': 9, 'key': 10, 'lantern': 11, 'motorbike': 12, 'necklace': 13, 'onion': 14, 'penguin': 15, 'raccoon': 16, 'sandwich': 17, 'table': 18, 'underwear': 19, 'vase': 20, 'watermelon': 21, 'yoga': 22, 'zigzag': 23}

# %%
classifier = TransformersFEClassifier(
              embedding_model_name="google/vit-base-patch16-224",
              classifier_model=LogisticRegression(),
              output_dir='.',
              data_path=DATA_DIR,
              label2idx=label2idx,
              device='cpu',
              seed=42)
# Out:
# model.safetensors:   0%|          | 0.00/346M [00:00<?, ?B/s]
# Some weights of ViTModel were not initialized from the model checkpoint at google/vit-base-patch16-224 and are newly initialized: ['vit.pooler.dense.bias', 'vit.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Loading images from train:   0%|          | 0/24 [00:00<?, ?it/s]
# Loading images from val:   0%|          | 0/24 [00:00<?, ?it/s]
# Loading images from test:   0%|          | 0/24 [00:00<?, ?it/s]

# %%
print(classifier.data)
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['image', 'labels'],
#         num_rows: 3315
#     })
#     val: Dataset({
#         features: ['image', 'labels'],
#         num_rows: 1097
#     })
#     test: Dataset({
#         features: ['image', 'labels'],
#         num_rows: 1100
#     })
# })

# %%
classifier.train()
# Out:
# Training model
# No embeddings found, computing them
# Map:   0%|          | 0/3315 [00:00<?, ? examples/s]
# Map:   0%|          | 0/1097 [00:00<?, ? examples/s]
# Map:   0%|          | 0/1100 [00:00<?, ? examples/s]
# Using MLflow experiment: Feature_Extraction

# %%
classifier.evaluate()
# Out:
# {'test_inference_time': 0.21034348222712818,
#  'test_accuracy': 0.84,
#  'test_weighted_precision': 0.8410468761107154,
#  'test_weighted_recall': 0.84,
#  'test_weighted_f1': 0.8387758570756424,
#  'test_macro_precision': 0.8371891373831812,
#  'test_macro_recall': 0.8373256378748276,
#  'test_macro_f1': 0.8354285731502314,
#  'test_micro_precision': 0.84,
#  'test_micro_recall': 0.84,
#  'test_micro_f1': 0.84,
#  'test_mcc': 0.8331843882228523}

# %% [markdown]
# # Random Forest

# %%
classifier = TransformersFEClassifier(
              embedding_model_name="google/vit-base-patch16-224",
              classifier_model=RandomForestClassifier(),
              output_dir='.',
              data_path=DATA_DIR,
              label2idx=label2idx,
              device='cpu',
              seed=42)
# Out:
# c:\Users\RAZER\AppData\Local\Programs\Python\Python310\lib\site-packages\transformers\models\vit\feature_extraction_vit.py:28: FutureWarning: The class ViTFeatureExtractor is deprecated and will be removed in version 5 of Transformers. Please use ViTImageProcessor instead.
#   warnings.warn(
# Some weights of ViTModel were not initialized from the model checkpoint at google/vit-base-patch16-224 and are newly initialized: ['vit.pooler.dense.bias', 'vit.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Loading images from train:   0%|          | 0/24 [00:00<?, ?it/s]
# Loading images from val:   0%|          | 0/24 [00:00<?, ?it/s]
# Loading images from test:   0%|          | 0/24 [00:00<?, ?it/s]

# %%
classifier.train()
# Out:
# Training model
# No embeddings found, computing them
# Map:   0%|          | 0/3315 [00:00<?, ? examples/s]
# Map:   0%|          | 0/1097 [00:00<?, ? examples/s]
# Map:   0%|          | 0/1100 [00:00<?, ? examples/s]
# Using MLflow experiment: Feature_Extraction

# %%
classifier.evaluate()
# Out:
# {'test_inference_time': 0.20029310108783344,
#  'test_accuracy': 0.7563636363636363,
#  'test_weighted_precision': 0.7676880216263194,
#  'test_weighted_recall': 0.7563636363636363,
#  'test_weighted_f1': 0.7546511898393649,
#  'test_macro_precision': 0.76398617399013,
#  'test_macro_recall': 0.7515620475901579,
#  'test_macro_f1': 0.7499505889864334,
#  'test_micro_precision': 0.7563636363636363,
#  'test_micro_recall': 0.7563636363636363,
#  'test_micro_f1': 0.7563636363636363,
#  'test_mcc': 0.7463511224089929}

# %% [markdown]
# # XGBOOST

# %%
classifier = TransformersFEClassifier(
                embedding_model_name="google/vit-base-patch16-224",
                classifier_model=XGBClassifier(),
                output_dir='.',
                data_path=DATA_DIR,
                label2idx=label2idx,
                device='cpu',
                seed=42)
# Out:
# c:\Users\RAZER\AppData\Local\Programs\Python\Python310\lib\site-packages\transformers\models\vit\feature_extraction_vit.py:28: FutureWarning: The class ViTFeatureExtractor is deprecated and will be removed in version 5 of Transformers. Please use ViTImageProcessor instead.
#   warnings.warn(
# Some weights of ViTModel were not initialized from the model checkpoint at google/vit-base-patch16-224 and are newly initialized: ['vit.pooler.dense.bias', 'vit.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Loading images from train:   0%|          | 0/24 [00:00<?, ?it/s]
# Loading images from val:   0%|          | 0/24 [00:00<?, ?it/s]
# Loading images from test:   0%|          | 0/24 [00:00<?, ?it/s]

# %%
classifier.train()
# Out:
# Training model
# No embeddings found, computing them
# Map:   0%|          | 0/3315 [00:00<?, ? examples/s]
# Map:   0%|          | 0/1097 [00:00<?, ? examples/s]
# Map:   0%|          | 0/1100 [00:00<?, ? examples/s]
# Using MLflow experiment: Feature_Extraction

# %%
classifier.evaluate()
# Out:
# {'test_inference_time': 0.2041385153269353,
#  'test_accuracy': 0.7581818181818182,
#  'test_weighted_precision': 0.7610195336089347,
#  'test_weighted_recall': 0.7581818181818182,
#  'test_weighted_f1': 0.7565842605634988,
#  'test_macro_precision': 0.7567073001354897,
#  'test_macro_recall': 0.75495971911039,
#  'test_macro_f1': 0.752632815372389,
#  'test_micro_precision': 0.7581818181818182,
#  'test_micro_recall': 0.7581818181818182,
#  'test_micro_f1': 0.7581818181818182,
#  'test_mcc': 0.7479314329692723}
